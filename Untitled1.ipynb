# %%
print('nikhil')
# Out:
# nikhil

# %%
import pandas as pd
df = pd.read_csv('Documents/EV Stats-1.csv')
df
# Out:
#     Sl. No                      State  \
# 0        1             Andhra Pradesh
# 1        2                      Assam
# 2        3                      Bihar
# 3        4               Chhattisgarh
# 4        5                      Delhi
# 5        6                        Goa
# 6        7                    Gujarat
# 7        8                    Haryana
# 8        9           Himachal Pradesh
# 9       10            Jammu & Kashmir
# 10      11                  Jharkhand
# 11      12                  Karnataka
# 12      13                     Kerala
# 13      14             Madhya Pradesh
# 14      15                Maharashtra
# 15      16                    Manipur
# 16      17                  Meghalaya
# 17      18                   Nagaland
# 18      19                     Odisha
# 19      20                     Punjab
# 20      21                  Rajasthan
# 21      22                 Tamil Nadu
# 22      23                  Telangana
# ...

# %%
import pandas as pd
student_data ={
    'names':['nikhil','suhas'],
    'usn':[127,60]
}
df = pd.DataFrame(student_data)
df
# Out:
#     names  usn
# 0  nikhil  127
# 1   suhas   60
